# %%
import numpy as np  
import pandas as pd
import random

# %%
df=pd.read_csv('tmdb_5000_movies.csv')
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
m=len(df.id)  
print(m)
# Out:
# 4803

# %%
numeric_cols = [cname for cname in df.columns if df[cname].dtype in ['int64', 'float64']]
df[numeric_cols]
# Out:
#          budget      id  popularity     revenue  runtime  vote_average  \
# 0     237000000   19995  150.437577  2787965087    162.0           7.2
# 1     300000000     285  139.082615   961000000    169.0           6.9
# 2     245000000  206647  107.376788   880674609    148.0           6.3
# 3     250000000   49026  112.312950  1084939099    165.0           7.6
# 4     260000000   49529   43.926995   284139100    132.0           6.1
# ...         ...     ...         ...         ...      ...           ...
# 4798     220000    9367   14.269792     2040920     81.0           6.6
# 4799       9000   72766    0.642552           0     85.0           5.9
# 4800          0  231617    1.444476           0    120.0           7.0
# 4801          0  126186    0.857008           0     98.0           5.7
# 4802          0   25975    1.929883           0     90.0           6.3
#
#       vote_count
# 0          11800
# 1           4500
# 2           4466
# 3           9106
# 4           2124
# ...

# %%
df = df[numeric_cols]
df.drop(columns=['id'],inplace=True)
# Out:
# C:\Users\H\AppData\Local\Temp\ipykernel_7780\3632150954.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['id'],inplace=True)

# %%
X=df.drop(columns=['revenue'])
Y=df['revenue']

# %%
df.head(4)
# Out:
#       budget  popularity     revenue  runtime  vote_average  vote_count
# 0  237000000  150.437577  2787965087    162.0           7.2       11800
# 1  300000000  139.082615   961000000    169.0           6.9        4500
# 2  245000000  107.376788   880674609    148.0           6.3        4466
# 3  250000000  112.312950  1084939099    165.0           7.6        9106

# %%
df=df.dropna()

# %%
df
# Out:
#          budget  popularity     revenue  runtime  vote_average  vote_count
# 0     237000000  150.437577  2787965087    162.0           7.2       11800
# 1     300000000  139.082615   961000000    169.0           6.9        4500
# 2     245000000  107.376788   880674609    148.0           6.3        4466
# 3     250000000  112.312950  1084939099    165.0           7.6        9106
# 4     260000000   43.926995   284139100    132.0           6.1        2124
# ...         ...         ...         ...      ...           ...         ...
# 4798     220000   14.269792     2040920     81.0           6.6         238
# 4799       9000    0.642552           0     85.0           5.9           5
# 4800          0    1.444476           0    120.0           7.0           6
# 4801          0    0.857008           0     98.0           5.7           7
# 4802          0    1.929883           0     90.0           6.3          16
#
# [4801 rows x 6 columns]

# %%
x1 = df["budget"]
x2 = df["popularity"]
x3 = df["runtime"]
x4 = df["vote_average"]
x5 = df["vote_count"]

y = df["revenue"]

print(x1.tail(10))
print(x2.head())
print(x3.head())
print(x4.head())
print(x5.head())

print(y.head())
len(x1)
# Out:
# 4793         0
# 4794         0
# 4795         0
# 4796      7000
# 4797         0
# 4798    220000
# 4799      9000
# 4800         0
# 4801         0
# 4802         0
# Name: budget, dtype: int64
# 0    150.437577
# 1    139.082615
# 2    107.376788
# 3    112.312950
# 4     43.926995
# Name: popularity, dtype: float64
# 0    162.0
# 1    169.0
# 2    148.0
# 3    165.0
# 4    132.0
# Name: runtime, dtype: float64
# 0    7.2
# 1    6.9
# 2    6.3
# 3    7.6
# 4    6.1
# Name: vote_average, dtype: float64
# 0    11800
# 1     4500
# 2     4466
# 3     9106
# 4     2124
# Name: vote_count, dtype: int64
# 0    2787965087
# 1     961000000
# 2     880674609
# 3    1084939099
# 4     284139100
# Name: revenue, dtype: int64
# 4801

# %%
from sklearn import preprocessing
n1=preprocessing.normalize([x1])
n2=preprocessing.normalize([x2])
n3=preprocessing.normalize([x3])
n4=preprocessing.normalize([x4])
n5=preprocessing.normalize([x5])
print(n1,n2,n3,n4,n5)
# Out:
# [[0.06837364 0.08654892 0.07068162 ... 0.         0.         0.        ]] [[0.05653927 0.05227171 0.04035565 ... 0.00054288 0.00032209 0.00072531]] [[0.02140241 0.0223272  0.01955282 ... 0.01585364 0.01294714 0.01189023]] [[0.01673691 0.01603954 0.01464479 ... 0.01627199 0.01325005 0.01464479]] [[1.20387026e-01 4.59103065e-02 4.55634286e-02 ... 6.12137420e-05
#   7.14160324e-05 1.63236645e-04]]

# %%
alpha=0.2
print(alpha)
# Out:
# 0.2

# %%
J = 100
n = 0 # Iteration Number
theta = [1,2,3,4,5,6]

cost_ls=[]

for i in range(100):

  print("Iteration number: ",n+1)
  n = n+1
  # Hypothesis Function
  h = []
  print("Hypothesis function value is: h0(x)=theta_0+theta_1 * x")
  for i2 in range(m):
    temp = theta[0] + theta[1]*n1[i2] + theta[2]*n2[i2]+theta[3]*n3[i2] + theta[4]*n4[i2] + theta[5]*n5[i2] 
    h.append(temp)
    
   # Cost Function
  error_sum = 0 
  print("Cost function is: j(theta)=1/(2*m) * i=1_samtionSign_m (h_theta_(x)-y)**2")

  for i3 in range(m):
    error_sum = error_sum + (h[i3] - y1[i3])**2

  J = (1/(2*m))*error_sum
  if J == float("inf") :
    theta = [random.randint(-100,100),random.randint(-100,100), random.randint(-100,100),random.randint(-100,100),random.randint(-100,100),random.randint(-100,100)] 
    continue
  print("\nCost function is:",J)
  cost_ls.append(J)
# Out:
# Iteration number:  1
# Hypothesis function value is: h0(x)=theta_0+theta_1 * x
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [27], in <cell line: 7>()
#      13 print("Hypothesis function value is: h0(x)=theta_0+theta_1 * x")
#      14 for i2 in range(m):
# ---> 15   temp = theta[0] + theta[1]*n1[i2] + theta[2]*n2[i2]+theta[3]*n3[i2] + theta[4]*n4[i2] + theta[5]*n5[i2]
#      16   h.append(temp)
#      18  # Cost Function
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
#Seaborn Visualization Library
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Create The Default Pairplot
#Printing Pairwise Plot
sns.pairplot(df)
plt.show()

# %%
#Ploting Heatmap
plt.figure(figsize=(12,10))
ax = sns.heatmap(df.corr())
